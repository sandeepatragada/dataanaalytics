# %%
import pandas as pd
import numpy as np
file_name="co2.csv"
df=pd.read_csv(file_name)
df.head(6) #first 6 rows
# Out:
#     Make       Model Vehicle Class  Engine Size(L)  Cylinders Transmission  \
# 0  ACURA         ILX       COMPACT             2.0          4          AS5
# 1  ACURA         ILX       COMPACT             2.4          4           M6
# 2  ACURA  ILX HYBRID       COMPACT             1.5          4          AV7
# 3  ACURA     MDX 4WD   SUV - SMALL             3.5          6          AS6
# 4  ACURA     RDX AWD   SUV - SMALL             3.5          6          AS6
# 5  ACURA         RLX      MID-SIZE             3.5          6          AS6
#
#   Fuel Type  Fuel Consumption City (L/100 km)  \
# 0         Z                               9.9
# 1         Z                              11.2
# 2         Z                               6.0
# 3         Z                              12.7
# 4         Z                              12.1
# 5         Z                              11.9
#
#    Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# ...

# %%
df.tail(10)  # Display last 10 rows/
# Out:
#        Make          Model          Vehicle Class  Engine Size(L)  Cylinders  \
# 7375  VOLVO     S90 T6 AWD               MID-SIZE             2.0          4
# 7376  VOLVO         V60 T5  STATION WAGON - SMALL             2.0          4
# 7377  VOLVO     V60 T6 AWD  STATION WAGON - SMALL             2.0          4
# 7378  VOLVO  V60 CC T5 AWD  STATION WAGON - SMALL             2.0          4
# 7379  VOLVO    XC40 T4 AWD            SUV - SMALL             2.0          4
# 7380  VOLVO    XC40 T5 AWD            SUV - SMALL             2.0          4
# 7381  VOLVO    XC60 T5 AWD            SUV - SMALL             2.0          4
# 7382  VOLVO    XC60 T6 AWD            SUV - SMALL             2.0          4
# 7383  VOLVO    XC90 T5 AWD         SUV - STANDARD             2.0          4
# 7384  VOLVO    XC90 T6 AWD         SUV - STANDARD             2.0          4
#
#      Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# ...

# %%
df.sample(5)  # Random sample of 5 rows
# Out:
#             Make                      Model          Vehicle Class  \
# 522      HYUNDAI                   VELOSTER                COMPACT
# 2154  VOLKSWAGEN                       GOLF                COMPACT
# 5834     GENESIS                    G90 AWD              FULL-SIZE
# 3552   CHEVROLET                    SONIC 5  STATION WAGON - SMALL
# 5542         BMW  M240i Coupe M Performance             SUBCOMPACT
#
#       Engine Size(L)  Cylinders Transmission Fuel Type  \
# 522              1.6          4          AM6         X
# 2154             1.8          4           M5         X
# 5834             5.0          8          AS8         Z
# 3552             1.4          4           M6         X
# 5542             3.0          6           M6         Z
#
#       Fuel Consumption City (L/100 km)  Fuel Consumption Hwy (L/100 km)  \
# 522                                8.6                              6.6
# 2154                               9.3                              6.4
# ...

# %%
df.info()  # Dataset structure
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7385 entries, 0 to 7384
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Make                              7385 non-null   object
#  1   Model                             7385 non-null   object
#  2   Vehicle Class                     7385 non-null   object
#  3   Engine Size(L)                    7385 non-null   float64
#  4   Cylinders                         7385 non-null   int64
#  5   Transmission                      7385 non-null   object
#  6   Fuel Type                         7385 non-null   object
#  7   Fuel Consumption City (L/100 km)  7385 non-null   float64
#  8   Fuel Consumption Hwy (L/100 km)   7385 non-null   float64
#  9   Fuel Consumption Comb (L/100 km)  7385 non-null   float64
#  10  Fuel Consumption Comb (mpg)       7385 non-null   int64
# ...

# %%
df.describe()  #  statistics
# Out:
#        Engine Size(L)    Cylinders  Fuel Consumption City (L/100 km)  \
# count     7385.000000  7385.000000                       7385.000000
# mean         3.160068     5.615030                         12.556534
# std          1.354170     1.828307                          3.500274
# min          0.900000     3.000000                          4.200000
# 25%          2.000000     4.000000                         10.100000
# 50%          3.000000     6.000000                         12.100000
# 75%          3.700000     6.000000                         14.600000
# max          8.400000    16.000000                         30.600000
#
#        Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# count                      7385.000000                       7385.000000
# mean                          9.041706                         10.975071
# std                           2.224456                          2.892506
# ...

# %%
df.shape  # Dimensions of dataset
# Out:
# (7385, 12)

# %%
df.size  # Total number of elements
# Out:
# 88620

# %%
df.columns  # Column names
# Out:
# Index(['Make', 'Model', 'Vehicle Class', 'Engine Size(L)', 'Cylinders',
#        'Transmission', 'Fuel Type', 'Fuel Consumption City (L/100 km)',
#        'Fuel Consumption Hwy (L/100 km)', 'Fuel Consumption Comb (L/100 km)',
#        'Fuel Consumption Comb (mpg)', 'CO2 Emissions(g/km)'],
#       dtype='object')

# %%
df.index  # Index range
# Out:
# RangeIndex(start=0, stop=7385, step=1)

# %%
df.memory_usage()  # Memory usage of each column
# Out:
# Index                                 128
# Make                                59080
# Model                               59080
# Vehicle Class                       59080
# Engine Size(L)                      59080
# Cylinders                           59080
# Transmission                        59080
# Fuel Type                           59080
# Fuel Consumption City (L/100 km)    59080
# Fuel Consumption Hwy (L/100 km)     59080
# Fuel Consumption Comb (L/100 km)    59080
# Fuel Consumption Comb (mpg)         59080
# CO2 Emissions(g/km)                 59080
# dtype: int64

# %%
df.nunique()  # Count of unique values in each column
# Out:
# Make                                  42
# Model                               2053
# Vehicle Class                         16
# Engine Size(L)                        51
# Cylinders                              8
# Transmission                          27
# Fuel Type                              5
# Fuel Consumption City (L/100 km)     211
# Fuel Consumption Hwy (L/100 km)      143
# Fuel Consumption Comb (L/100 km)     181
# Fuel Consumption Comb (mpg)           54
# CO2 Emissions(g/km)                  331
# dtype: int64

# %%
df.dtypes  # Data types of each column
# Out:
# Make                                 object
# Model                                object
# Vehicle Class                        object
# Engine Size(L)                      float64
# Cylinders                             int64
# Transmission                         object
# Fuel Type                            object
# Fuel Consumption City (L/100 km)    float64
# Fuel Consumption Hwy (L/100 km)     float64
# Fuel Consumption Comb (L/100 km)    float64
# Fuel Consumption Comb (mpg)           int64
# CO2 Emissions(g/km)                   int64
# dtype: object

# %%
df.isnull().sum()  # Count missing values per column
# Out:
# Make                                0
# Model                               0
# Vehicle Class                       0
# Engine Size(L)                      0
# Cylinders                           0
# Transmission                        0
# Fuel Type                           0
# Fuel Consumption City (L/100 km)    0
# Fuel Consumption Hwy (L/100 km)     0
# Fuel Consumption Comb (L/100 km)    0
# Fuel Consumption Comb (mpg)         0
# CO2 Emissions(g/km)                 0
# dtype: int64

# %%
df.duplicated().sum()  # Count duplicated rows
# Out:
# 1103

# %%
df.drop_duplicates()  # Drop duplicate rows
# Out:
#        Make        Model   Vehicle Class  Engine Size(L)  Cylinders  \
# 0     ACURA          ILX         COMPACT             2.0          4
# 1     ACURA          ILX         COMPACT             2.4          4
# 2     ACURA   ILX HYBRID         COMPACT             1.5          4
# 3     ACURA      MDX 4WD     SUV - SMALL             3.5          6
# 4     ACURA      RDX AWD     SUV - SMALL             3.5          6
# ...     ...          ...             ...             ...        ...
# 7380  VOLVO  XC40 T5 AWD     SUV - SMALL             2.0          4
# 7381  VOLVO  XC60 T5 AWD     SUV - SMALL             2.0          4
# 7382  VOLVO  XC60 T6 AWD     SUV - SMALL             2.0          4
# 7383  VOLVO  XC90 T5 AWD  SUV - STANDARD             2.0          4
# 7384  VOLVO  XC90 T6 AWD  SUV - STANDARD             2.0          4
#
#      Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 0             AS5         Z                               9.9
# ...

# %%
df.reset_index(drop=True)  # Reset index
# Out:
#        Make        Model   Vehicle Class  Engine Size(L)  Cylinders  \
# 0     ACURA          ILX         COMPACT             2.0          4
# 1     ACURA          ILX         COMPACT             2.4          4
# 2     ACURA   ILX HYBRID         COMPACT             1.5          4
# 3     ACURA      MDX 4WD     SUV - SMALL             3.5          6
# 4     ACURA      RDX AWD     SUV - SMALL             3.5          6
# ...     ...          ...             ...             ...        ...
# 7380  VOLVO  XC40 T5 AWD     SUV - SMALL             2.0          4
# 7381  VOLVO  XC60 T5 AWD     SUV - SMALL             2.0          4
# 7382  VOLVO  XC60 T6 AWD     SUV - SMALL             2.0          4
# 7383  VOLVO  XC90 T5 AWD  SUV - STANDARD             2.0          4
# 7384  VOLVO  XC90 T6 AWD  SUV - STANDARD             2.0          4
#
#      Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 0             AS5         Z                               9.9
# ...

# %%
df.rename(columns={'old_col': 'new_col'}, inplace=True)  # Rename a column

# %%
df.sort_values('CO2 Emissions(g/km)', ascending=True)  # Sort by CO2 Emissions(g/km)
# Out:
#              Make               Model Vehicle Class  Engine Size(L)  \
# 5931      HYUNDAI          IONIQ Blue     FULL-SIZE             1.6
# 6950      HYUNDAI          IONIQ Blue     FULL-SIZE             1.6
# 3824      HYUNDAI          IONIQ BLUE     FULL-SIZE             1.6
# 4900      HYUNDAI          IONIQ BLUE     FULL-SIZE             1.6
# 6949      HYUNDAI               IONIQ     FULL-SIZE             1.6
# ...           ...                 ...           ...             ...
# 6046  LAMBORGHINI  Aventador Roadster    TWO-SEATER             6.5
# 7059  LAMBORGHINI  Aventador Roadster    TWO-SEATER             6.5
# 5575      BUGATTI              Chiron    TWO-SEATER             8.0
# 6640      BUGATTI              Chiron    TWO-SEATER             8.0
# 4509      BUGATTI              CHIRON    TWO-SEATER             8.0
#
#       Cylinders Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 5931          4          AM6         X                               4.2
# ...

# %%
df.nlargest(10, 'CO2 Emissions(g/km)')  # Top 10 rows with highest carbon emisson
# Out:
#                Make               Model    Vehicle Class  Engine Size(L)  \
# 4509        BUGATTI              CHIRON       TWO-SEATER             8.0
# 5575        BUGATTI              Chiron       TWO-SEATER             8.0
# 6640        BUGATTI              Chiron       TWO-SEATER             8.0
# 6046    LAMBORGHINI  Aventador Roadster       TWO-SEATER             6.5
# 7059    LAMBORGHINI  Aventador Roadster       TWO-SEATER             6.5
# 349            FORD          E350 WAGON  VAN - PASSENGER             6.8
# 6045    LAMBORGHINI     Aventador Coupe       TWO-SEATER             6.5
# 7058    LAMBORGHINI     Aventador Coupe       TWO-SEATER             6.5
# 2971  MERCEDES-BENZ            AMG G 65   SUV - STANDARD             6.0
# 5126  MERCEDES-BENZ            AMG G 65   SUV - STANDARD             6.0
#
#       Cylinders Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 4509         16          AM7         Z                              26.8
# ...

# %%
df.nsmallest(10, 'CO2 Emissions(g/km)')# Top 10 rows with lowest 'carbon emission'

# %%
df.select_dtypes(include=['number']).corr() # Correlation matrix
# Out:
#                                   Engine Size(L)  Cylinders  \
# Engine Size(L)                          1.000000   0.927653
# Cylinders                               0.927653   1.000000
# Fuel Consumption City (L/100 km)        0.831379   0.800702
# Fuel Consumption Hwy (L/100 km)         0.761526   0.715252
# Fuel Consumption Comb (L/100 km)        0.817060   0.780534
# Fuel Consumption Comb (mpg)            -0.757854  -0.719321
# CO2 Emissions(g/km)                     0.851145   0.832644
#
#                                   Fuel Consumption City (L/100 km)  \
# Engine Size(L)                                            0.831379
# Cylinders                                                 0.800702
# Fuel Consumption City (L/100 km)                          1.000000
# Fuel Consumption Hwy (L/100 km)                           0.948180
# Fuel Consumption Comb (L/100 km)                          0.993810
# Fuel Consumption Comb (mpg)                              -0.927059
# ...

# %%
df.select_dtypes(include=['number']).cov() # Covariance matrix
# Out:
#                                   Engine Size(L)  Cylinders  \
# Engine Size(L)                          1.833778   2.296719
# Cylinders                               2.296719   3.342705
# Fuel Consumption City (L/100 km)        3.940709   5.124150
# Fuel Consumption Hwy (L/100 km)         2.293939   2.908921
# Fuel Consumption Comb (L/100 km)        3.200380   4.127766
# Fuel Consumption Comb (mpg)            -7.421812  -9.510924
# CO2 Emissions(g/km)                    67.441418  89.075474
#
#                                   Fuel Consumption City (L/100 km)  \
# Engine Size(L)                                            3.940709
# Cylinders                                                 5.124150
# Fuel Consumption City (L/100 km)                         12.251919
# Fuel Consumption Hwy (L/100 km)                           7.382726
# Fuel Consumption Comb (L/100 km)                         10.061890
# Fuel Consumption Comb (mpg)                             -23.467157
# ...

# %%
df.select_dtypes(include=['number']).kurtosis()  # Kurtosis of each column
# Out:
# Engine Size(L)                     -0.131963
# Cylinders                           1.525175
# Fuel Consumption City (L/100 km)    1.196145
# Fuel Consumption Hwy (L/100 km)     2.008969
# Fuel Consumption Comb (L/100 km)    1.393575
# Fuel Consumption Comb (mpg)         2.499369
# CO2 Emissions(g/km)                 0.478801
# dtype: float64

# %%
df.select_dtypes(include=['number']).skew()  # Skewness of each column
# Out:
# Engine Size(L)                      0.809181
# Cylinders                           1.110415
# Fuel Consumption City (L/100 km)    0.809005
# Fuel Consumption Hwy (L/100 km)     1.079217
# Fuel Consumption Comb (L/100 km)    0.893316
# Fuel Consumption Comb (mpg)         0.977034
# CO2 Emissions(g/km)                 0.526094
# dtype: float64
